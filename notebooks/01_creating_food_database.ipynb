# %% [markdown]
# # 01.- CREATING FOOD DATABASE

# %% [markdown]
# We will start building our dataset scrapping the information from [BEDCA](https://www.bedca.net/bdpub/index.php) the Spanish Food Composition
# Database published by the Ministry of Science and Innovation and under the coordination and funding
# of the Spanish Agency for Food Safety and Nutrition of the Ministry of Health, Social Services and Equality.
#
# The food composition values collected in this database have been obtained from different sources that
# include laboratories, the food industry and scientific publications or have been calculated by the agency.
#
# Our databse will be stored in a `pandas.DataFrame`.

# %% [markdown]
# ___
# ### PREREQUISITES

# %%
# !pip install selenium
# !pip install webdriver-manager

# %% [markdown]
# ___
# ### IMPORTS

# %%
import numpy as np
import pandas as pd

from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
from funcs_data import mklist, item_to_lists, nameof

from funcs_driver import launch_driver, goto, foodindex, get_in, get_back

from funcs_scrapping import get_general_info, get_nutritional_facts
from funcs_scrapping import refine_nutritional_facts, get_group_info

# %%
# This cell only needs to be executed to update funcs_driver
# and funcs_scrapping after them have been imported

# %run funcs_data
# %run funcs_driver.py
# %run funcs_scrapping.py

# %% [markdown]
# ___
# ### BUILDING THE DATAFRAME ( I )

# %% [markdown]
# Reading up on [different ways to increase a DataFrame](https://stackoverflow.com/questions/13784192/creating-an-empty-pandas-dataframe-then-filling-it) lead me to build a list for every column to be
# grown via `list.append()` and then build the `pd.DataFrame`

# %%
# The DataFrame will be made of a group de characteristics that we will use as columns
characteristics = ['foodname_ESP', 'foodname_ENG', 'quantity',
                   'energy', 'fats', 'prot', 'water', 'fiber',
                   'carbs', 'm_unsat_fats', 'p_unsat_fats',
                   'sat_fats', 'palm_acid', 'chol', 'A', 'D', 'E',
                   'B9', 'B3', 'B2', 'B1', 'B12', 'B6', 'C', 'calcium',
                   'iron', 'potassium', 'magnesium', 'sodium', 'phosphorus',
                   'iodide', 'selenium', 'zinc']

general_info =  ['foodname_ESP', 'foodname_ENG', 'quantity',]
macros =        ['energy', 'fats', 'prot', 'carbs']
complementary = ['water', 'fiber', 'm_unsat_fats', 'p_unsat_fats',
                 'sat_fats', 'chol']
flags =         ['palm_acid']
vitamins =      ['A', 'D', 'E', 'B9', 'B3', 'B2', 'B1', 'B12', 'B6', 'C',]
minerals =      ['calcium', 'iron', 'potassium', 'magnesium', 'sodium',
                 'phosphorus', 'iodide', 'selenium', 'zinc',]

# Lets generate all lists with the help of a short func build 'ad hoc'
foodname_ESP, foodname_ENG, quantity = mklist(len(general_info))
energy, fats, prot, carbs = mklist(len(macros))
water, fiber, m_unsat_fats, p_unsat_fats, sat_fats, chol = mklist(len(complementary))  
palm_acid = []
calcium, iron, potassium, magnesium, sodium, phosphorus, iodide, selenium, zinc = mklist(len(minerals))
A, D, E, B9, B3, B2, B1, B12, B6, C = mklist(len(vitamins))

# To make it easier to add elements to every list, a 'superlist' is created
lists = [foodname_ESP, foodname_ENG, quantity,
         energy, fats, prot, water, fiber,
         carbs, m_unsat_fats, p_unsat_fats,
         sat_fats, palm_acid, chol, A, D, E,
         B9, B3, B2, B1, B12, B6, C, calcium, iron,
         potassium, magnesium, sodium, phosphorus,
         iodide, selenium, zinc]

# %% [markdown]
# With all the lists created its time to make them grow with the scrapped data

# %% [markdown]
# ___
# ### SCRAPPING

# %%
# Build the driver using Firefox as navigator
driver = launch_driver()
# Out:
# ====== WebDriver manager ======
# Current firefox version is 96.0
# Get LATEST geckodriver version for 96.0 firefox
# Driver [/Users/mabatalla/.wdm/drivers/geckodriver/macos/v0.30.0/geckodriver] found in cache

# %%
# With the base URL of the database the program will go to the all-food list
url = 'https://www.bedca.net/bdpub/index.php'
goto(driver, url)

# %%
# Generating an iterator with every food found
num_of_foods = len(foodindex(driver))

for i in range(num_of_foods):
    # The website refreshes everytime we go in and out of a food
    # so it so the iterator needs to be regenerated at every loop
    foods = foodindex(driver)
    item = []
    
    # Get in - Get data
    get_in(foods[i])
    get_general_info(driver, item)
    get_nutritional_facts(driver, item)
    refine_nutritional_facts(driver, item)

    # Add information found to lists
    item_to_lists(item, lists)

    # Get out
    get_back(driver)
    
    ### CHECKPOINT ###
    # In case of exception just change the range
    # at the top for range(last_i_printed, num_of_foods):
    print(i, foodname_ESP[i])
# Out:
# 0 Aceite de algodón
# 1 Aceite de cacahuete
# 2 Aceite de coco
# 3 Aceite de colza
# 4 Aceite de germen de trigo
# 5 Aceite de girasol
# 6 Aceite de grano de uva
# 7 Aceite de hígado de bacalao
# 8 Aceite de lino
# 9 Aceite de nuez
# 10 Aceite de oliva
# 11 Aceite de oliva virgen extra
# 12 Aceite de oliva virgen extra, producción ecologica
# 13 Aceite de palma
# 14 Aceite de sésamo
# 15 Aceite de soja
# 16 Aceituna
# 17 Aceituna negra, con hueso
# 18 Acelga, cruda
# 19 Acelga, en conserva
# 20 Acelgas, hervidas
# 21 Achicoria, cruda
# 22 Agua de la red
# 23 Agua mineral, mineralización debil
# 24 Agua, con gas, embotellada
# 25 Aguacate
# 26 Aguacate congelado
# 27 Aguardiente
# 28 Ajo
# 29 Ajo, en polvo
# 30 Ajo, frito
# 31 Albahaca
# 32 Albaricoque
# 33 Albondigas en conserva
# 34 Alcachofa, cruda
# 35 Alcachofas en conserva
# 36 Alcaparra
# 37 Alioli
# 38 Almeja
# 39 Almejas en conserva
# 40 Almendra, cruda
# 41 Almendra, cruda, con cáscara
# 42 Almendra, frita, salada
# 43 Almendra, tostada
# 44 Almidón de arroz
# 45 Almidón de maíz
# 46 Almidón de trigo
# 47 Altramuz
# 48 Alubia blanca, en conserva
# 49 Alubia blanca, seca, cruda
# 50 Alubia negra, seca, remojada, hervida
# 51 Anacardo, crudo
# 52 Anchoas en aceite vegetal
# 53 Anguila, al horno
# 54 Anguila, cruda
# 55 Anguila, hervida
# 56 Angula, cruda
# 57 Anís, seco
# 58 Aperitivos de trigo
# 59 Apio, crudo
# 60 Apio, en conserva en salmuera
# 61 Arandano
# 62 Arenque, ahumado
# 63 Arenque, salado
# 64 Arroz
# 65 Arroz con leche
# 66 Arroz hinchado, para el desayuno, enriquecido
# 67 Arroz integral, crudo
# 68 Arroz integral, hervido
# 69 Arroz, hervido
# 70 Atún en aceite de oliva isabel
# 71 Atun en aceite vegetal
# 72 Atún en escabeche
# 73 Atún, al horno
# 74 Atún, al natural
# 75 Atún, crudo
# 76 Atún, plancha
# 77 Avellana
# 78 Avellana, cruda, con cáscara
# 79 Avena, cruda
# 80 Avestruz, solomillo, crudo
# 81 Azafrán
# 82 Azúcar blanca
# 83 Azúcar, moreno
# 84 Bacaladilla
# 85 Bacalao, ahumado
# 86 Bacalao, crudo
# 87 Bacalao, fresco, al horno
# 88 Bacalao, frito
# 89 Bacalao, salado, crudo
# 90 Bacalao, salado, remojado, crudo
# 91 Bacón, ahumado, a la parrilla
# 92 Bacon, crudo, con grasa separable
# 93 Bambú, crudo
# 94 Barra chocolate, tipo "bounty"
# 95 Barra de chocolate, tipo "Kit-kat"
# 96 Barra de chocolate, tipo "Mars"
# 97 Barrita cereales con chocolate
# 98 Barrita cereales con frutas
# 99 Barrita cereales maíz y trigo
# 100 Barrita cereales trigo y chocolate
# 101 Batido de chocolate
# 102 Batido de fresa
# 103 Batido de soja
# 104 Batido fermentado de soja
# 105 Batido lácteo de cacao, bajo en calorías
# 106 Batido lácteo, de fresa, bajo en calorías
# 107 Bebida de soja
# 108 Bebida energética
# 109 Bebida isotónica
# 110 Berberechos
# 111 Berberechos en conserva
# 112 Berenjena
# 113 Berenjena, frita, en aceite de girasol
# 114 Berro, crudo
# 115 Besugo
# 116 Bígaro, hervido
# 117 Bizcocho
# 118 Bocadillo
# 119 Bogavante
# 120 Bogavante, hervido
# 121 Bollería, genérico
# 122 Bombón
# 123 Boniato, crudo
# 124 Bonito del norte, al vapor
# 125 Bonito del norte, enlatado en aceite de soja
# 126 Bonito en aceite vegetal
# 127 Bonito, enlatado en aceite, escurrido
# 128 Boquerón
# 129 Boquerón, frito
# 130 Borraja
# 131 Breca, cruda
# 132 Brécol, crudo
# 133 Brécol, hervido
# 134 Butifarra
# 135 Caballa, al horno
# 136 Caballa, cruda
# 137 Caballa, enlatada en aceite, escurrida
# 138 Cabracho o rascacio, crudo
# 139 Cabrito lechal, costillar, asado
# 140 Cabrito lechal, costillar, crudo
# 141 Cabrito lechal, espalda, cruda
# 142 Cabrito lechal, pierna, cruda
# 143 Cabrito, parte s/e, crudo, con grasa separable
# 144 Cacahuete, crudo, con cáscara
# 145 Cacahuete, frito, salado
# 146 Cacahuete, tostado, salado
# 147 Cacao en polvo, azucarado
# 148 Cacao, en polvo, azucarado, bajo en calorías
# 149 Café, con leche
# 150 Café, en grano o molido, descafeinado
# 151 Café, en polvo, sin reconstituir
# 152 Café, en polvo, soluble
# 153 Café, infusión
# 154 Café, infusión, descafeinado
# 155 Café, sucedáneo, soluble
# 156 Calabacín
# 157 Calabacín, asado
# 158 Calabaza, cruda
# 159 Calabaza, hervida
# 160 Calamar, asado
# 161 Calamar, conserva
# 162 Calamar, crudo
# 163 Calamares en aceite vegetal
# 164 Caldo vegetal
# 165 Callos de ternera
# 166 Camarón
# 167 Canela, en polvo
# 168 Canelones
# 169 Cangrejo
# 170 Cangrejo de río crudo
# 171 Cangrejo, en conserva
# 172 Canonigos
# 173 Caqui
# 174 Caracol
# 175 Caramelo
# 176 Cardo
# 177 Cardo, tallo, en conserva
# 178 Carne de cerdo de capa blanca, cabezada, parte magra, cruda
# 179 Carne de cerdo de capa blanca, cabezada, partes grasa y magra, crudo
# 180 Carne de cerdo de capa blanca, chuleta, parte magra, cruda
# 181 Carne de cerdo de capa blanca, chuleta, partes grasa y magra, cruda
# 182 Carne de cerdo de capa blanca, jamón, parte magra, crudo
# 183 Carne de cerdo de capa blanca, jamón, partes grasa y magra, crudo
# 184 Carne de cerdo de capa blanca, lomo, parte magra, crudo
# 185 Carne de cerdo de capa blanca, lomo, partes grasa y magra, crudo
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193 Carne picada
# 194 Carpa, al horno
# 195 Carpa, cruda
# 196 Castaña, cruda
# 197 Castaña, tostada
# 198 Cava
# 199 Caviar
# 200 Cebada, cruda
# 201 Cebolla
# 202 Cebolla, asada
# 203 Cebolla, hervida
# 204 Cebollino, crudo
# 205 Cecina
# 206 Centeno, crudo
# 207 Centollo, crudo
# 208 Cerdo, chuleta, crudo
# 209 Cerdo, costilla, crudo
# 210 Cerdo, lomo, asado
# 211 Cerdo, lomo, crudo
# 212 Cerdo, panceta, cruda
# 213 Cerdo, parte sin especificar
# 214 Cerdo, pierna, cruda, con grasa separable
# 215 Cerdo, solomillo, asado
# 216 Cerdo, solomillo, crudo
# 217 Cereales base trigo y chocolate
# 218 Cereales desayuno base de arroz chocolateado
# 219 Cereales desayuno base de arroz y miel
# 220 Cereales desayuno base de arroz, trigo y fruta
# 221 Cereales desayuno base de maíz y miel
# 222 Cereales desayuno base de maíz y trigo
# 223 Cereales desayuno base de maíz, trigo y avena
# 224 Cereales desayuno base de trigo azucarado
# 225 Cereales desayuno base de trigo y arroz
# 226 Cereales desayuno base de trigo y frutas
# 227 Cereales desayuno base de trigo y miel
# 228 Cereales desayuno base de trigo, avena, maiz y miel
# 229 Cereales desayuno base de trigo, avena, maíz, miel y nueces
# 230 Cereales desayuno base muesli
# 231 Cereales desayuno, maíz azucarado
# 232 Cereales para el desayuno, ricos en fibra, tipo "all-bran"
# 233 Cereales, en polvo, solubles (eko)
# 234 Cereza
# 235 Cerveza con alcohol
# 236 Cerveza sin alcohol
# 237 Cerveza, baja en alcohol
# 238 Cerveza, oscura, 8°- 9°
# 239 Champiñon
# 240 Champiñones en conserva
# 241 Chayote, crudo
# 242 Chicle, sin azúcar
# 243 Chile, rojo
# 244 Chile, verde
# 245 Chipiron
# 246 Chirimoya
# 247 Chirla
# 248 Chistorra
# 249 Chocolate blanco
# 250 Chocolate con leche
# 251 Chocolate con leche y almendras
# 252 Chocolate con leche y arroz
# 253 Chocolate con nueces de macadamia
# 254 Chocolate negro, con almendras
# 255 Chocolate negro, con azúcar
# 256 Chocolate, negro
# 257 Choped pork
# 258 Chorizo
# 259 Chufa, cruda
# 260 Churro
# 261 Ciervo, parte s/e, crudo, con grasa separable
# 262 Cigala
# 263 Ciruela, con piel, cruda
# 264 Ciruela, sin piel
# 265 Coco, desecado
# 266 Coco, fresco
# 267 Col blanca, cruda
# 268 Col de bruselas, cruda
# 269 Col lombarda, hervida
# 270 Col rizada, cruda
# 271 Coliflor, congelada, cruda
# 272 Coliflor, hervida
# 273 Comino
# 274 Complejo vitaminico
# 275 Coñac
# 276 Conejo de granja, carne, cruda
# 277 Conejo, entero, estofado
# 278 Confitura, frutas s/e, baja en calorías
# 501 Margarina de maíz
# 502 Margarina, baja en calorías
# 503 Masa de hojaldre, cruda
# 504 Mayonesa con aceite de girasol
# 505 Mayonesa, aceite de oliva
# 506 Mayonesa, aceite de soja
# 507 Mayonesa, baja en calorías
# 508 Mejillon
# 509 Mejillón, en conserva, al natural
# 510 Mejillón, en escabeche
# 511 Mejillón, hervido
# 512 Melocotón
# 513 Melocotón en almíbar
# 514 Melocotón, desecado
# 515 Melón
# 516 Membrillo, crudo
# 517 Menestra de verduras, congelada
# 518 Menta, fresca
# 519 Merluza fresca
# 520 Merluza, congelada, cruda
# 521 Merluza, rebozada, frita
# 522 Mermelada de albaricoque
# 523 Mermelada de albaricoque y melocotón, baja en calorías
# 524 Mermelada de ciruela
# 525 Mermelada de frambuesa
# 526 Mermelada de fresa
# 527 Mermelada de fresa, baja en calorías
# 528 Mermelada de grosella roja
# 529 Mermelada de mora
# 530 Mermelada de naranja
# 531 Mero, crudo
# 532 Mero, plancha
# 533 Miel
# 534 Mijo
# 535 Miso
# 536 Mojo picon
# 537 Molleja de cordero
# 538 Morcilla
# 539 Morcilla, frita
# 540 Mortadela
# 541 Mostaza
# 542 Mousse de chocolate
# 543 Mousse de queso fresco, con frutas
# 544 Mousse de queso fresco, desnatado, azucarado
# 545 Mousse de queso fresco, desnatado, con frutas
# 546 Mousse de yogur, con frutas
# 547 Mousse de yogur, natural
# 548 Muesli
# 549 Mújol, al horno
# 550 Mújol, crudo
# 551 Nabo, pelado, crudo
# 552 Napolitana, rellena con crema de cacao
# 553 Naranja
# 554 Nata montada
# 555 Nata, líquida, para cocinar, 18% de grasa
# 556 Natillas sabor vainilla
# 557 Nécora
# 558 Néctar de albaricoque, envasado
# 559 Néctar de ciruela
# 560 Néctar de frutas exóticas, envasado
# 561 Néctar de mango, envasado
# 562 Néctar de maracuyá, envasado
# 563 Néctar de melocotón
# 564 Néctar de naranja, envasado
# 565 Néctar de pera, envasado
# 566 Néctar de piña
# 567 Néctar de pomelo
# 568 Nectarina
# 569 Níscalo, crudo
# 570 Níspero, con piel, crudo
# 571 Nispero, conserva en su jugo
# 572 Nispero, sin piel , congelado
# 573 Nuez
# 574 Nuez moscada
# 575 Nuez, cruda, con cáscara
# 576 Oca, sin piel, asada
# 577 Orégano, seco
# 578 Ostra, cruda
# 579 Paella
# 580 Paella marinera
# 581 Palmera
# 582 Palmito, en conserva
# 583 Palometa, cruda
# 584 Palomitas de maíz, sin aceite, sin sal
# 585 Pan blanco, de barra
# 586 Pan blanco, de barra, sin sal
# 587 Pan blanco, de molde, tostado
# 588 Pan blanco, frito
# 589 Pan blanco, tipo "baguette"
# 590 Pan blanco, tostado
# 591 Pan blanco, tostado sin sal
# 592 Pan de avena
# 593 Pan de cebada
# 594 Pan de centeno
# 595 Pan de leche
# 596 Pan de maíz
# 597 Pan integral
# 598 Pan integral, de molde, tostado
# 599 Pan integral, sin sal
# 600 Pan integral, tostado
# 601 Pan rallado
# 602 Pan tostado integral
# 603 Pan, tipo hamburguesa
# 604 Panceta, frita
# 605 Panga, cruda
# 606 Papaya, cruda
# 607 Paraguaya
# 707 Queso afuega'l pitu
# 708 Queso ahumado de aliva
# 709 Queso azul
# 710 Queso brie
# 711 Queso cabra, curado
# 712 Queso cabrales
# 713 Queso Camembert 20-30% MG/ES
# 714 Queso camembert 60% mg/es
# 715 Queso cantabria
# 716 Queso casín
# 717 Queso Castellano
# 718 Queso cebreiro
# 719 Queso Cheddar
# 720 Queso curado, genérico
# 721 Queso de aracena
# 722 Queso de arzúa
# 723 Queso de bola
# 724 Queso de cádiz
# 725 Queso de Castilla-La Mancha, oveja y cabra
# 726 Queso de Castilla-La Mancha, oveja, vaca y cabra
# 727 Queso de castilla-león, oveja y vaca
# 728 Queso de murcia, al vino
# 729 Queso de tenerife
# 730 Queso de tiétar
# 731 Queso edam
# 732 Queso emmental
# 733 Queso en porciones
# 734 Queso flor de guía
# 735 Queso fresco de burgos
# 736 Queso fresco, cabra
# 737 Queso fresco, desnatado, con frutas
# 738 Queso fundido, extragraso (>60% MG/ES)
# 739 Queso gata-hurdes
# 740 Queso gaztazarra
# 741 Queso Gouda
# 742 Queso grazalema
# 743 Queso Gruyer
# 744 Queso herreño
# 745 Queso Ibores
# 746 Queso Mahón
# 747 Queso majorero
# 748 Queso manchego
# 749 Queso manchego, en aceite
# 750 Queso mozzarella
# 751 Queso munster
# 752 Queso para untar
# 753 Queso para untar, con finas hierbas
# 754 Queso para untar, con salmón
# 755 Queso para untar, natural, bajo en calorías
# 756 Queso parmesano
# 757 Queso pasiego
# 758 Queso pedroches
# 759 Queso peñamellera
# 760 Queso picón
# 761 Queso porrúa
# 762 Queso Raclette
# 763 Queso rallado, genérico
# 764 Queso roquefort
# 765 Queso San Simón
# 766 Queso semicurado, genérico
# 767 Queso serrat
# 768 Queso servilleta
# 769 Queso Tetilla
# 770 Queso tierno, genérico
# 771 Queso torta del casar
# 772 Queso tupí
# 773 Queso Zamorano
# 774 Quinoa, cruda
# 775 Rábano
# 776 Rabo de toro
# 777 Rape, a la parrilla
# 778 Rape, crudo
# 779 Rape, plancha
# 780 Raya, cruda
# 781 Refresco "tipo gaseosa"
# 782 Refresco con gas, sabor cola, sin cafeina
# 783 Refresco con gas, sabor cola, sin cafeina, bajo en calorías
# 784 Refresco de té
# 785 Refresco de té, bajo en calorías
# 786 Refresco tipo "tónica"
# 787 Refresco, con gas, sabor naranja
# 788 Refresco, sabor cola
# 789 Refresco, sabor cola, bajo en calorías
# 790 Refresco, sabor limón, con gas
# 791 Refresco, sabor naranja, sin gas
# 792 Regaliz
# 793 Remolacha, en conserva
# 794 Repollo
# 795 Requesón
# 796 Riñón, de cordero, crudo
# 797 Riñón, de ternera, crudo
# 798 Rodaballo
# 799 Rollito de primavera
# 800 Romero
# 801 Ron
# 802 Rosquilla
# 803 Rúcula
# 804 Sal de mar
# 805 Sal yodada
# 806 Salami
# 807 Salchicha de pollo fresca
# 808 Salchicha, fresca
# 809 Salchicha, tipo "frankfurt"
# 810 Salchicha, tipo país, a la plancha
# 811 Salchicha, tipo viena
# 812 Salchichón
# 813 Salema, cruda
# 814 Salmón
# 815 Salmón ahumado
# 816 Salmón, plancha
# 817 Salmonete
# 818 Salsa agridulce
# 819 Salsa al curry
# 820 Salsa al roquefort
# 821 Salsa barbacoa
# 822 Salsa bechamel
# 823 Salsa boloñesa
# 824 Salsa carbonara
# 825 Salsa de queso
# 826 Salsa de soja
# 827 Salsa napolitana
# 828 Salsa siciliana, picante
# 829 Salsa vinagreta, con aceite de oliva
# 830 Salvado de trigo
# 831 San jacobo, congelado
# 832 Sandía
# 833 Sangría
# 834 Sardina
# 835 Sardina, asada
# 836 Sardina, enlatada, en aceite, escurrida
# 837 Sardina, enlatada, en escabeche
# 838 Sargo, crudo
# 839 Seitán
# 840 Semilla de lino
# 841 Sémola de trigo, cruda
# 842 Sémola de trigo, hervida
# 843 Sepia
# 844 Sésamo, semilla
# 845 Sesos, de cerdo, crudos
# 846 Sesos, de cordero, crudos
# 847 Sesos, de ternera, crudos
# 848 Seta
# 849 Seta, plancha
# 850 Sidra
# 851 Sobao
# 852 Sobrasada
# 853 Soda
# 854 Sofrito
# 855 Soja, fresca
# 856 Soja, frita
# 857 Soja, germinada, en conserva
# 858 Soja, seca, cruda
# 859 Soja, seca, remojada, hervida
# 860 Sopa de sobre maravilla
# 861 Sopa de sobre, sin reconstituir
# 862 Suplemento proteico
# 863 Surimi
# 864 Tabasco
# 865 Tapioca, hervida
# 866 Té, infusión, con leche
# 867 Tenca, cruda
# 868 Tequila
# 869 Ternera, costilla, cruda
# 870 Ternera, lomo, crudo, con grasa separable
# 871 Ternera, parte s/e, asada
# 872 Ternera, parte sin especificar, cruda, con grasa separable
# 873 Ternera, solomillo, asado
# 874 Ternera, solomillo, sin grasa, crudo
# 875 Tocino
# 876 Tofu
# 877 Tomate
# 878 Tomate frito
# 879 Tomate, asado
# 880 Tomate, maduro, pelado y triturado, enlatado
# 881 Tomate, maduro, puré
# 882 Tomillo, seco
# 883 Torta de aceite
# 884 Tortilla, a la francesa
# 885 Trigo, entero, crudo
# 886 Trucha
# 887 Trucha, ahumada
# 888 Trufa, cruda
# 889 Turrón, tipo Alicante
# 890 Uva blanca
# 891 Uva blanca, congelada
# 892 Uva negra, cruda
# 893 Uva pasa
# 894 Vaca/buey, parte s/e, asado
# 895 Vaca/buey, parte s/e, estofado
# 896 Vaca/buey, solomillo, a la plancha
# 897 Vaca/buey, solomillo, crudo
# 898
# 899
# 900 Vainilla
# 901 Vermut, s/e
# 902 Vieira
# 903 Vieja, cruda
# 904 Vinagre balsámico
# 905 Vinagre de manzana
# 906 Vinagre de vino
# 907 Vino blanco
# 908 Vino dulce, tipo oporto
# 909 Vino rosado
# 910 Vino tinto
# 911 Vodka
# 912 Volador, crudo
# 913 Whisky
# 914 Yogur griego
# 915 Yogur líquido, "tipo actimel"
# 916 Yogur líquido, aromatizado sabor s/e
# 917 Yogur líquido, con frutas s/e
# 918 Yogur líquido, entero, con cereales
# 919 Yogur líquido, natural, azucarado
# 920 Yogur, búlgaro
# 921 Yogur, desnatado, aromatizado sabor s/e
# 922 Yogur, desnatado, con cereales
# 923 Yogur, desnatado, con cereales, manzana y ciruela
# 924 Yogur, desnatado, con cereza y frambuesa
# 925 Yogur, desnatado, con ciruela, albaricoque y fibra
# 926 Yogur, desnatado, con fresa, grosella y fibra
# 927 Yogur, desnatado, con frutas
# 928 Yogur, desnatado, con frutas del bosque
# 929 Yogur, desnatado, con frutas tropicales
# 930 Yogur, desnatado, con manzana
# 931 Yogur, desnatado, con melocotón y maracuyá
# 932 Yogur, desnatado, con melocotón, frambuesa y fibra
# 933 Yogur, desnatado, con piña y pomelo
# 934 Yogur, desnatado, sabor natural
# 935 Yogur, desnatado, sabor natural, azucarado
# 936 Yogur, desnatado, sabor vainilla
# 937 Yogur, enriquecido, con frutas
# 938 Yogur, enriquecido, natural
# 939 Yogur, enriquecido, natural, azucarado
# 940 Yogur, enriquecido, natural, con nata
# 941 Yogur, enriquecido, sabor, s/e
# 942 Yogur, entero, con cereales y fresas
# 943 Yogur, entero, con fresas
# 944 Yogur, entero, con frutas del bosque
# 945 Yogur, líquido, desnatado, natural
# 946 Yogur, líquido, entero, con fresas
# 947 Yogur, líquido, entero, con frutas
# 948 Yogur, líquido, entero, sabor fresa
# 949 Yogur, líquido, entero, sabor fresa y plátano
# 950 Yogur, líquido, entero, sabor frutas del bosque
# 951 Yogur, líquido, entero, sabor piña y coco
# 952 Zamburiñas
# 953 Zanahoria, cruda
# 954 Zumo de grosella negra
# 955 Zumo de grosella roja
# 956 Zumo de lima, envasado
# 957 Zumo de limón, fresco
# 958 Zumo de mango
# 959 Zumo de manzana
# 960 Zumo de naranja
# 961 Zumo de piña
# 962 Zumo de piña y uva
# 963 Zumo de pomelo, envasado
# 964 Zumo de tomate, fresco
# 965 Zumo de uva
# 966 Zumo de uva y melocotón
# 967 Zumo de zanahoria, fresco

# %% [markdown]
# The webscrapping took 115 mins. It's time to close the driver.

# %%
driver.close()

# %% [markdown]
# ___
# ### BUILDING THE DATAFRAME ( II )

# %% [markdown]
# With all foods inspected and all lists filled its time to finish the `pd.DataFrame` construction

# %%
data = {k: v for k, v in zip(characteristics, lists)}

nutritional_values = pd.DataFrame(data)
nutritional_values.set_index(['foodname_ESP', 'foodname_ENG'], inplace=True)

# %% [markdown]
# Let's take a quicklook to the DataFrame

# %%
nutritional_values.head()
# Out:
#                                          quantity  energy   fats  prot  water  \
# foodname_ESP              foodname_ENG
# Aceite de algodón         Cotton oil          100   888.0  100.0   0.0    0.0
# Aceite de cacahuete       Peanut oil          100   887.0   99.9   0.0    0.1
# Aceite de coco            Coconut oil         100   888.0  100.0   0.0    0.0
# Aceite de colza           Rape oil            100   888.0  100.0   0.0    0.0
# Aceite de germen de trigo Wheat germ oil      100   887.0   99.9   0.0    0.1
#
#                                           fiber  carbs  m_unsat_fats  \
# foodname_ESP              foodname_ENG
# Aceite de algodón         Cotton oil        0.0    0.0         17.80
# Aceite de cacahuete       Peanut oil        0.0    0.0         47.80
# Aceite de coco            Coconut oil       0.0    0.0          4.96
# Aceite de colza           Rape oil          0.0    0.0         65.30
# Aceite de germen de trigo Wheat germ oil    0.0    0.0         15.10
#
#                                           p_unsat_fats  sat_fats  ...    C  \
# foodname_ESP              foodname_ENG                            ...
# Aceite de algodón         Cotton oil             51.90     25.90  ...  0.0
# Aceite de cacahuete       Peanut oil             28.50     18.80  ...  0.0
# Aceite de coco            Coconut oil             0.77     84.31  ...  0.0
# Aceite de colza           Rape oil               28.01      6.29  ...  0.0
# Aceite de germen de trigo Wheat germ oil         61.70     18.80  ...  0.0
#
#                                           calcium  iron  potassium  magnesium  \
# foodname_ESP              foodname_ENG
# Aceite de algodón         Cotton oil          0.0   0.0        0.0        0.0
# Aceite de cacahuete       Peanut oil          0.0   NaN        0.0        0.0
# Aceite de coco            Coconut oil         0.0   0.4        0.0        0.0
# Aceite de colza           Rape oil            0.0   0.0        0.0        0.0
# Aceite de germen de trigo Wheat germ oil      0.0   0.0        NaN        NaN
#
#                                           sodium  phosphorus  iodide  \
# foodname_ESP              foodname_ENG
# Aceite de algodón         Cotton oil         0.0         0.0     0.0
# Aceite de cacahuete       Peanut oil         0.0         0.0     0.0
# Aceite de coco            Coconut oil        0.0         0.0     0.0
# Aceite de colza           Rape oil           0.0         0.0     NaN
# Aceite de germen de trigo Wheat germ oil     NaN         NaN     0.0
#
#                                           selenium  zinc
# foodname_ESP              foodname_ENG
# Aceite de algodón         Cotton oil           0.0   0.0
# Aceite de cacahuete       Peanut oil           NaN   0.0
# Aceite de coco            Coconut oil          0.0   0.0
# Aceite de colza           Rape oil             0.0   0.0
# Aceite de germen de trigo Wheat germ oil       NaN   NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# And export as `.csv` the database

# %%
nutritional_values.to_csv('./data/foods_raw.csv', encoding='utf-8')

# %% [markdown]
# ___
# ### THE MORE YOU KNOW...

# %% [markdown]
# Our database also contains information on which food group each food belongs to.
# Due to the navigation operation is high time consuming to code, I prefered to get this information by hand,
# clicking on the driver to access to the desired page and then letting the scrapper get the information

# %%
dairy_group = get_group_info(driver, dairy_group)

# %%
eggs_group = get_group_info(driver, eggs_group)

# %%
meat_group = get_group_info(driver, meat_group)

# %%
seafood_group = get_group_info(driver, seafood_group)

# %%
fats_oils_group = get_group_info(driver, fats_oils_group)

# %%
cereals_group = get_group_info(driver, cereals_group)

# %%
legumes_group = get_group_info(driver, legumes_group)

# %%
vegetables_group = get_group_info(driver, vegetables_group)

# %%
fruits_group = get_group_info(driver, fruits_group)

# %%
sweets_group = get_group_info(driver, sweets_group)

# %%
drinks_group = get_group_info(driver, drinks_group)

# %%
misc_group = get_group_info(driver, misc_group)

# %%
groups = [dairy_group, eggs_group, meat_group,
          seafood_group, fats_oils_group, cereals_group,
          legumes_group, vegetables_group, fruits_group,
          sweets_group, drinks_group, misc_group]

# %% [markdown]
# ##### Let's take a quicklook at the information of the groups

# %%
num_of_items = 0
for group in groups:
    num_of_items += len(group)
    print(len(group), 'items in', nameof(group, globals()))
    
print(num_of_items, 'items in total')

# %% [markdown]
# Now let's build a `pd.Series` for each group and export them as `.csv` later on so we can import them again.

# %%
for group in groups:
    name_of_Series = nameof(group, globals())
    series = pd.Series(group, name=f'{name_of_Series}')
    series.to_csv(f'./data/{name_of_Series}.csv', encoding='utf-8')

# %%
# There was an error with misc_group name (see cell above)
# This cell overwrites the corresponding Series

name_of_Series = 'misc_group'
series = pd.Series(misc_group, name=f'{name_of_Series}')
series.to_csv(f'./data/{name_of_Series}.csv', encoding='utf-8')
